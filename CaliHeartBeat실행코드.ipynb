# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/CaliHeartBeat/SafeSSL-Calibration
# Out:
# /content/drive/MyDrive/Colab Notebooks/CaliHeartBeat/SafeSSL-Calibration

# %%
ls
# Out:
# checkpoints_ecg/        configs_debug/  main/         README.md         utils/
# checkpoints_fixmatch/   configs.py      models/       requirements.txt
# checkpoints_openmatch/  datasets/       ptbxl/        scripts/
# checkpoints_test/       jupyters/       __pycache__/  tasks/

# %%
# 1. Pillow 버전을 '딱 10.0.1(==)'에서 '10.0.1 이상(>=)'으로 변경합니다.
# !sed -i 's/Pillow==10.0.1/Pillow>=10.0.1/g' requirements.txt

# 2. (선택) 혹시 모를 다른 패키지 충돌 방지를 위해 numpy 등도 유연하게 풉니다.
# !sed -i 's/==/>=/g' requirements.txt
# 1. 잘못된 패키지 이름 'skimage'를 'scikit-image'로 수정합니다.
# !sed -i 's/skimage/scikit-image/g' requirements.txt

# 2. 다시 설치 실행
# !pip install -r requirements.txt

# %%
import os
# 예: '내 드라이브'는 '/content/drive/MyDrive' 입니다.
project_path = '/content/drive/MyDrive/Colab Notebooks/CaliHeartBeat/SafeSSL-Calibration'
os.chdir(project_path)

# %%
ls
# Out:
# checkpoints_ecg/        configs_debug/  main/         README.md         utils/
# checkpoints_fixmatch/   configs.py      models/       requirements.txt
# checkpoints_openmatch/  datasets/       ptbxl/        scripts/
# checkpoints_test/       jupyters/       __pycache__/  tasks/

# %%
# !pip install wfdb scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 153.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# ...

# %%
# PYTHONPATH=. 필수 (datasets 모듈 인식용)
# !PYTHONPATH=. python ./main/run_PROPOSED.py \
    --gpus 0 \
    --seed 1 \
    --server main \
    --data ptbxl \
    --root ./ptbxl \
    --backbone-type resnet1d \
    --n-label-per-class 50 \
    --mismatch-ratio 0.3 \
    --iterations 50000 \
    --warm-up 500 \
    --save-every 1000 \
    --batch-size 64 \
    --learning-rate 0.001 \
    --optimizer adam \
    --lambda-ova-cali 0.1 \
    --lambda-ova 0.1 \
    --weight-decay 0 \
    --normalize \
    --checkpoint-root ./checkpoints_ecg
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/CaliHeartBeat/SafeSSL-Calibration/./main/run_PROPOSED.py", line 14, in <module>
#     from datasets.cifar import CIFAR, load_CIFAR
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1191, in get_data
# KeyboardInterrupt
# ^C

# %%
#2 PYTHONPATH=. 필수 (datasets 모듈 인식용)
# !PYTHONPATH=. python ./main/run_PROPOSED.py \
    --gpus 0 \
    --seed 1 \
    --server main \
    --data ptbxl \
    --root ./ptbxl \
    --backbone-type resnet1d \
    --n-label-per-class 50 \
    --mismatch-ratio 0.3 \
    --iterations 50000 \
    --warm-up 500 \
    --save-every 1000 \
    --batch-size 64 \
    --learning-rate 0.001 \
    --optimizer adam \
    --lambda-ova-cali 0.1 \
    --lambda-ova 0.1 \
    --weight-decay 0 \
    --normalize \
    --checkpoint-root ./checkpoints_ecg
# Out:
# 2025-12-05 08:15:51.844180: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-05 08:15:51.862523: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764922551.884204   44053 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764922551.890745   44053 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# 위에 꺼에서 calimatch 실험성공

# %%
#3 PYTHONPATH=. 필수 (datasets 모듈 인식용)
# !PYTHONPATH=. python ./main/run_PROPOSED.py \
    --gpus 0 \
    --seed 1 \
    --server main \
    --data ptbxl \
    --root ./ptbxl \
    --backbone-type resnet1d \
    --n-label-per-class 50 \
    --mismatch-ratio 0.3 \
    --iterations 50000 \
    --warm-up 500 \
    --save-every 1000 \
    --batch-size 64 \
    --learning-rate 0.001 \
    --optimizer adam \
    --lambda-ova-cali 0.1 \
    --lambda-ova 0.1 \
    --weight-decay 0 \
    --normalize \
    --checkpoint-root ./checkpoints_ecg

# %% [markdown]
# 비교군 ) fixmatch

# %%
# !PYTHONPATH=. python ./main/run_FIXMATCH.py \
    --gpus 0 \
    --seed 1 \
    --server main \
    --data ptbxl \
    --root ./ptbxl \
    --backbone-type resnet1d \
    --n-label-per-class 50 \
    --mismatch-ratio 0.3 \
    --iterations 50000 \
    --warm-up 500 \
    --save-every 1000 \
    --batch-size 64 \
    --learning-rate 0.001 \
    --optimizer adam \
    --weight-decay 0 \
    --checkpoint-root ./checkpoints_fixmatch
# Out:
# 2025-12-06 08:04:39.340529: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-06 08:04:39.358991: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765008279.380582    8144 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765008279.387197    8144 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# 비교군 ) IOMatch

# %%
# !PYTHONPATH=. python ./main/run_IOMATCH.py \
    --gpus 0 \
    --seed 1 \
    --server main \
    --data ptbxl \
    --root ./ptbxl \
    --backbone-type resnet1d \
    --n-label-per-class 50 \
    --mismatch-ratio 0.3 \
    --iterations 50000 \
    --warm-up 500 \
    --save-every 1000 \
    --batch-size 64 \
    --learning-rate 0.001 \
    --optimizer adam \
    --weight-decay 0 \
    --p-cutoff 0.95 \
    --lambda-open 1.0 \
    --checkpoint-root ./checkpoints_iomatch
# Out:
# 2025-12-07 11:18:47.227431: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-07 11:18:47.245216: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765106327.266410    9935 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765106327.272864    9935 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
